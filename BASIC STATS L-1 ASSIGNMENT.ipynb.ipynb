# %% [markdown]
# #                                                 [ DATA SCIENCE ] Assignment
# ## BASIC STATISTICS_LEVEL-1
# ### S.AKHIL
# #### Gmail : akhilsangamrjasn@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv('sales_data_with_discounts.csv')
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %% [markdown]
# # Datatypes df.dtypes

# %%
df.dtypes 
    #0r
print(df.dtypes)
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %% [markdown]
# # info()

# %%
df.info()
  #or
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# ...

# %% [markdown]
# # DESCRIPTIVE STATISTICS

# %% [markdown]
# # max()

# %%
# return the non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=['number']).columns 
print("Non-numeric columns:", non_numeric_cols)

# Identify numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns
print("Numeric columns:", numeric_columns)
# Out:
# Non-numeric columns: Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')
# Numeric columns: Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#find maximum value in specific column
df['Volume'].max()
     #or
print(df['Volume'].max())
# Out:
# 31

# %%
# specific number of columns
specific_columns = ['Volume', 'Avg Price', 'Total Sales Value']

# find maximum value in specific number of columns
df[specific_columns].max()
            #or
print(df[specific_columns].max())
# Out:
# Volume                   31
# Avg Price             60100
# Total Sales Value    196400
# dtype: int64

# %%
# returns the maximum values of every column
df.max(axis=0)
     #or
print(df.max(axis=0))
# Out:
# Date                    15-04-2021
# Day                      Wednesday
# SKU                            M10
# City                             C
# Volume                          31
# BU                         Mobiles
# Brand                         YouM
# Model                   YM-99 Plus
# Avg Price                    60100
# Total Sales Value           196400
# Discount Rate (%)        19.992407
# Discount Amount       25738.022194
# Net Sales Value      179507.479049
# dtype: object

# %% [markdown]
# # min()

# %%
# find maximum value in specific column
print(df['Volume'].min())
     #or
df['Volume'].min()
# Out:
# 1
# 1

# %%
# find minimum value in specific number of columns
df[specific_columns].min()
          #or
print(df[specific_columns].min())
# Out:
# Volume                 1
# Avg Price            290
# Total Sales Value    400
# dtype: int64

# %%
# returns the minimum values of every column
df.min(axis=0)
     #or
print(df.min(axis=0))
# Out:
# Date                   01-04-2021
# Day                        Friday
# SKU                           F01
# City                            C
# Volume                          1
# BU                           FMCG
# Brand                      Babaji
# Model                Babaji Cream
# Avg Price                     290
# Total Sales Value             400
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# dtype: object

# %% [markdown]
# # count()

# %%
# count it returns values present in data frame
# find COUNT in specific column
df['Volume'].count()
    #or
print(df['Volume'].count())
# Out:
# 450

# %%
# find COUNT for specific number of columns
df[specific_columns].count()
          #or
print(df[specific_columns].count())
# Out:
# Volume               450
# Avg Price            450
# Total Sales Value    450
# dtype: int64

# %%
# returns the COUNT for every column
df.count(axis=0)
     #or
print(df.count(axis=0))
# Out:
# Date                 450
# Day                  450
# SKU                  450
# City                 450
# Volume               450
# BU                   450
# Brand                450
# Model                450
# Avg Price            450
# Total Sales Value    450
# Discount Rate (%)    450
# Discount Amount      450
# Net Sales Value      450
# dtype: int64

# %% [markdown]
# # mean()

# %%
# find MEAN in specific column
df['Volume'].mean()
    #or
print(df['Volume'].mean())
# Out:
# 5.066666666666666

# %%
# find MEAN for specific number of columns
df[specific_columns].mean()
          #or
print(df[specific_columns].mean())
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# dtype: float64

# %%
# returns the MEAN for every column
# df.mean(axis=0)
     #or
#print(df.mean(axis=0)) [  MEAN ONLY FOR NUMERICAL COLUMNS,we have categorical columns also ]

# %% [markdown]
# # sum()

# %%
# find SUM in specific column
df['Volume'].sum()
    #or
print(df['Volume'].sum())
# Out:
# 2280

# %%
# find SUM for specific number of columns
df[specific_columns].sum()
          #or
print(df[specific_columns].sum())
# Out:
# Volume                   2280
# Avg Price             4704045
# Total Sales Value    15215776
# dtype: int64

# %%
# returns the SUM for every column
df.sum(axis=0)
     #or
print(df.sum(axis=0)) # categorie columns also added
# Out:
# Date                 01-04-202101-04-202101-04-202101-04-202101-04-...
# Day                  ThursdayThursdayThursdayThursdayThursdayThursd...
# SKU                  M01M02M03M04M05M06M07M08M09M10F01F02F03F04F05F...
# City                 CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC...
# Volume                                                            2280
# BU                   MobilesMobilesMobilesMobilesMobilesMobilesMobi...
# Brand                RealURealUYouMYouMYouMRealUSumsangSumsangOrang...
# Model                RU-10RU-9 PlusYM-99YM-99 PlusYM-98 RU-9S-20S-2...
# Avg Price                                                      4704045
# Total Sales Value                                             15215776
# Discount Rate (%)                                          6819.858853
# Discount Amount                                         1505924.740954
# Net Sales Value                                        13709851.259072
# dtype: object

# %% [markdown]
# # median()

# %%
# find MEDIAN in specific column
df['Volume'].median()
    #or
print(df['Volume'].median())
# Out:
# 4.0

# %%
# find MEDIAN for specific number of columns
df[specific_columns].median()
          #or
print(df[specific_columns].median())
# Out:
# Volume                  4.0
# Avg Price            1450.0
# Total Sales Value    5700.0
# dtype: float64

# %%
# returns the MEDIAN for every column
# df.median(axis=0)
     #or
#print(df.median(axis=0)) [ MEDIAN ONLY FOR NUMERICAL COLUMNS,we have categorical columns also ]

# %% [markdown]
# # mode()

# %%
# find MODE in specific column
df['Volume'].mode()
    #or
print(df['Volume'].mode())
# Out:
# 0    3
# Name: Volume, dtype: int64

# %%
# find MODE for specific number of columns
df[specific_columns].mode()
          #or
print(df[specific_columns].mode())
# Out:
#    Volume  Avg Price  Total Sales Value
# 0     3.0        400            24300.0
# 1     NaN        450                NaN
# 2     NaN        500                NaN
# 3     NaN       1300                NaN
# 4     NaN       8100                NaN

# %%
# returns the MODE for every column
df.mode(axis=0)
     #or
print(df.mode(axis=0)) # categorie columns also have repeation
# Out:
#            Date       Day  SKU City  Volume         BU  Brand           Model  \
# 0    01-04-2021  Thursday  F01    C     3.0       FMCG  Jeera    Babaji Cream
# 1    02-04-2021       NaN  F02  NaN     NaN  Lifestyle    NaN     Babaji Oil
# 2    03-04-2021       NaN  F03  NaN     NaN    Mobiles    NaN  Babaji Shampoo
# 3    04-04-2021       NaN  F04  NaN     NaN        NaN    NaN   Gear BB Cream
# 4    05-04-2021       NaN  F05  NaN     NaN        NaN    NaN      Gear Cream
# ..          ...       ...  ...  ...     ...        ...    ...             ...
# 445         NaN       NaN  NaN  NaN     NaN        NaN    NaN             NaN
# 446         NaN       NaN  NaN  NaN     NaN        NaN    NaN             NaN
# 447         NaN       NaN  NaN  NaN     NaN        NaN    NaN             NaN
# 448         NaN       NaN  NaN  NaN     NaN        NaN    NaN             NaN
# 449         NaN       NaN  NaN  NaN     NaN        NaN    NaN             NaN
#
# ...

# %% [markdown]
# # Quartiles - quantile()

# %%
# find QUARTILE in specific column
df['Volume'].quantile()
    #or
print(df['Volume'].quantile())
# Out:
# 4.0

# %%
# find QUARTILE for specific number of columns
df[specific_columns].quantile()
          #or
print(df[specific_columns].quantile())
# Out:
# Volume                  4.0
# Avg Price            1450.0
# Total Sales Value    5700.0
# Name: 0.5, dtype: float64

# %%
# returns the MODE for every column
#df.quantile(axis=0)
     #or
#print(df.quantile(axis=0)) # Quartile ONLY FOR NUMERICAL COLUMNS,we have categorical columns also ]

# %% [markdown]
# # VARIANCE var()

# %%
# find VARIANCE in specific column
df['Volume'].var()
    #or
print(df['Volume'].var())
# Out:
# 17.906458797327417

# %%
# find VARIANCE for specific number of columns
df[specific_columns].var()
          #or
print(df[specific_columns].var())
# Out:
# Volume               1.790646e+01
# Avg Price            3.268830e+08
# Total Sales Value    2.553794e+09
# dtype: float64

# %%
# returns VARIANCE for every column
#df.var(axis=0)
     #or
#print(df.var(axis=0)) # VARIANCE ONLY FOR NUMERICAL COLUMNS,we have categorical columns also ]

# %% [markdown]
# # STANDARD DEVIATION std()

# %%
# find STANDARD DEVIATION in specific column
df['Volume'].std()
    #or
print(df['Volume'].std())
# Out:
# 4.231602391213926

# %%
# find STANDARD DEVIATION for specific number of columns
df[specific_columns].std()
          #or
print(df[specific_columns].std())
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# dtype: float64

# %%
# returns STANDARD DEVIATION for every column
#df.std(axis=0)
     #or
#print(df.std(axis=0)) # STANDARD DEVIATION ONLY FOR NUMERICAL COLUMNS,we have categorical columns also ]

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# ## HISTOGRAM

# %%
# Plot histograms for each numerical column 
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns 

for column in numerical_columns: 
    df[column].hist(bins=30,color='r',edgecolor='black') 
    plt.title(f'Histogram of {column}') 
    plt.xlabel(column) 
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# # BOXPLOT

# %%
# Create boxplots for each numerical column
for column in numerical_columns:
    df.boxplot(column=column)
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# # BAR CHART

# %%
# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Create bar charts for each categorical column
for column in categorical_columns:
    df[column].value_counts().plot(kind='bar', edgecolor='black')
    plt.title(f'Bar Chart of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()
